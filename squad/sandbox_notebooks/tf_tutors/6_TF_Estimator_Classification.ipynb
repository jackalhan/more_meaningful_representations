# %%
import pandas as pd

# %%
diabetes = pd.read_csv('pima-indians-diabetes.csv')

# %%
diabetes.head()
# Out:
#    Number_pregnant  Glucose_concentration  Blood_pressure   Triceps   Insulin  \
# 0                6               0.743719        0.590164  0.353535  0.000000
# 1                1               0.427136        0.540984  0.292929  0.000000
# 2                8               0.919598        0.524590  0.000000  0.000000
# 3                1               0.447236        0.540984  0.232323  0.111111
# 4                0               0.688442        0.327869  0.353535  0.198582
#
#         BMI  Pedigree  Age  Class Group
# 0  0.500745  0.234415   50      1     B
# 1  0.396423  0.116567   31      0     C
# 2  0.347243  0.253629   32      1     B
# 3  0.418778  0.038002   21      0     B
# 4  0.642325  0.943638   33      1     C

# %%
diabetes.columns
# Out:
# Index(['Number_pregnant', 'Glucose_concentration', 'Blood_pressure', 'Triceps',
#        'Insulin', 'BMI', 'Pedigree', 'Age', 'Class', 'Group'],
#       dtype='object')

# %%
#columns to be normalized
cols_to_norm = ['Number_pregnant', 'Glucose_concentration', 'Blood_pressure', 'Triceps',
       'Insulin', 'BMI', 'Pedigree']

# %%
diabetes[cols_to_norm] = diabetes[cols_to_norm].apply(lambda x: (x - x.min())/ (x.max() - x.min()))

# %%
diabetes.head()
# Out:
#    Number_pregnant  Glucose_concentration  Blood_pressure   Triceps   Insulin  \
# 0         0.352941               0.743719        0.590164  0.353535  0.000000
# 1         0.058824               0.427136        0.540984  0.292929  0.000000
# 2         0.470588               0.919598        0.524590  0.000000  0.000000
# 3         0.058824               0.447236        0.540984  0.232323  0.111111
# 4         0.000000               0.688442        0.327869  0.353535  0.198582
#
#         BMI  Pedigree  Age  Class Group
# 0  0.500745  0.234415   50      1     B
# 1  0.396423  0.116567   31      0     C
# 2  0.347243  0.253629   32      1     B
# 3  0.418778  0.038002   21      0     B
# 4  0.642325  0.943638   33      1     C

# %%
import tensorflow as tf
# Out:
# /home/jackalhan/Development/github/more_meaningful_representations/venv/lib/python3.5/site-packages/h5py/__init__.py:36: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   from ._conv import register_converters as _register_converters

# %%
diabetes.columns
# Out:
# Index(['Number_pregnant', 'Glucose_concentration', 'Blood_pressure', 'Triceps',
#        'Insulin', 'BMI', 'Pedigree', 'Age', 'Class', 'Group'],
#       dtype='object')

# %%
# continous feature columns with tf
num_preg = tf.feature_column.numeric_column('Number_pregnant')
plasma_gluc = tf.feature_column.numeric_column('Glucose_concentration')
dias_press = tf.feature_column.numeric_column('Blood_pressure')
tricep = tf.feature_column.numeric_column('Triceps')
insulin = tf.feature_column.numeric_column('Insulin')
bmi = tf.feature_column.numeric_column('BMI')
diabetes_predigree = tf.feature_column.numeric_column('Pedigree')
age = tf.feature_column.numeric_column('Age')

# %%
# non continous values, categorical values
# 2 options, DICT and HASH BUCKET
# We are going to see the two of them.

# %%
assigned_group = tf.feature_column.categorical_column_with_vocabulary_list('Group', ['A', 'B', 'C','D'])

# %%
#If we do not know all the groupings, if there is tons of groupsings, we can use the hash bucket
#Tensorflow is defining groups based on the name we provide as a column and the size. We can have a bigger size
# although real grouping is smllaer than this size, on the backgound tf is handling it. 
# -------------------------------
# assigned_group = tf.feature_column.categorical_column_with_hash_bucket('Group', hash_bucket_size=10)
# -------------------------------

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
# 20 bins in this histogram
diabetes['Age'].hist(bins=20)
# this hist tells us that what are the sizes of the age in the age range 
# basically, distributions of the ages

# %%
#this is going to create the buckets of values between 20 and 30, 30 and 40, 50 and......
# continous numeric into categorical columns
age_bucket = tf.feature_column.bucketized_column(age, boundaries=[20,30,40,50,60,70,80])

# %%
feat_cols = [num_preg, plasma_gluc, dias_press, tricep, insulin, bmi, diabetes_predigree, 
            assigned_group,age_bucket]

# %%
# TRAIN TEST SPLIT
x_data = diabetes.drop('Class', axis=1)
x_data.head()
# Out:
#    Number_pregnant  Glucose_concentration  Blood_pressure   Triceps   Insulin  \
# 0         0.352941               0.743719        0.590164  0.353535  0.000000
# 1         0.058824               0.427136        0.540984  0.292929  0.000000
# 2         0.470588               0.919598        0.524590  0.000000  0.000000
# 3         0.058824               0.447236        0.540984  0.232323  0.111111
# 4         0.000000               0.688442        0.327869  0.353535  0.198582
#
#         BMI  Pedigree  Age Group
# 0  0.500745  0.234415   50     B
# 1  0.396423  0.116567   31     C
# 2  0.347243  0.253629   32     B
# 3  0.418778  0.038002   21     B
# 4  0.642325  0.943638   33     C

# %%
labels = diabetes['Class']
labels

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(x_data, labels, test_size = 0.3, random_state=101)

# %%
# now estimator time
input_func = tf.estimator.inputs.pandas_input_fn(x= X_train, y=y_train,
                                                batch_size=10, num_epochs=1000,
                                                shuffle=True)

# %%
##############################
# LINEAR CLASSIFIER
##############################
model = tf.estimator.LinearClassifier(feature_columns=feat_cols, n_classes=2)
# Out:
# INFO:tensorflow:Using default config.
# WARNING:tensorflow:Using temporary folder as model directory: /tmp/tmpe3xlybcj
# INFO:tensorflow:Using config: {'_keep_checkpoint_every_n_hours': 10000, '_save_summary_steps': 100, '_keep_checkpoint_max': 5, '_task_id': 0, '_num_ps_replicas': 0, '_is_chief': True, '_tf_random_seed': None, '_num_worker_replicas': 1, '_service': None, '_master': '', '_log_step_count_steps': 100, '_save_checkpoints_secs': 600, '_session_config': None, '_cluster_spec': <tensorflow.python.training.server_lib.ClusterSpec object at 0x7fb92f5c89e8>, '_save_checkpoints_steps': None, '_model_dir': '/tmp/tmpe3xlybcj', '_task_type': 'worker'}

# %%
model.train(input_func,steps=1000)
# Out:
# INFO:tensorflow:Create CheckpointSaverHook.
# INFO:tensorflow:Saving checkpoints for 1 into /tmp/tmpe3xlybcj/model.ckpt.
# INFO:tensorflow:loss = 6.931472, step = 1
# INFO:tensorflow:global_step/sec: 44.2889
# INFO:tensorflow:loss = 6.7352667, step = 101 (2.259 sec)
# INFO:tensorflow:global_step/sec: 44.9319
# INFO:tensorflow:loss = 5.4966593, step = 201 (2.225 sec)
# INFO:tensorflow:global_step/sec: 45.3692
# INFO:tensorflow:loss = 5.349855, step = 301 (2.204 sec)
# INFO:tensorflow:global_step/sec: 45.8861
# INFO:tensorflow:loss = 5.684064, step = 401 (2.181 sec)
# INFO:tensorflow:global_step/sec: 46.3572
# INFO:tensorflow:loss = 5.745453, step = 501 (2.155 sec)
# INFO:tensorflow:global_step/sec: 41.9523
# INFO:tensorflow:loss = 5.1855636, step = 601 (2.385 sec)
# INFO:tensorflow:global_step/sec: 46.3282
# INFO:tensorflow:loss = 7.367931, step = 701 (2.161 sec)
# INFO:tensorflow:global_step/sec: 44.8144
# INFO:tensorflow:loss = 4.840305, step = 801 (2.229 sec)
# INFO:tensorflow:global_step/sec: 45.6003
# INFO:tensorflow:loss = 5.8363733, step = 901 (2.193 sec)
# INFO:tensorflow:Saving checkpoints for 1000 into /tmp/tmpe3xlybcj/model.ckpt.
# INFO:tensorflow:Loss for final step: 4.3290067.

# %%
eval_input_func = tf.estimator.inputs.pandas_input_fn(x=X_test, y=y_test, 
                                                      batch_size=10, 
                                                      num_epochs=1,
                                                      shuffle=False)

# %%
results = model.evaluate(eval_input_func)
# Out:
# WARNING:tensorflow:Casting <dtype: 'float32'> labels to bool.
# WARNING:tensorflow:Casting <dtype: 'float32'> labels to bool.
# INFO:tensorflow:Starting evaluation at 2018-03-28-00:35:27
# INFO:tensorflow:Restoring parameters from /tmp/tmpe3xlybcj/model.ckpt-1000
# INFO:tensorflow:Finished evaluation at 2018-03-28-00:35:28
# INFO:tensorflow:Saving dict for global step 1000: accuracy = 0.7316017, accuracy_baseline = 0.64935064, auc = 0.8048971, auc_precision_recall = 0.648346, average_loss = 0.52251774, global_step = 1000, label/mean = 0.35064936, loss = 5.029233, prediction/mean = 0.35382357

# %%
results
# Out:
# {'accuracy': 0.7316017,
#  'accuracy_baseline': 0.64935064,
#  'auc': 0.8048971,
#  'auc_precision_recall': 0.648346,
#  'average_loss': 0.52251774,
#  'global_step': 1000,
#  'label/mean': 0.35064936,
#  'loss': 5.029233,
#  'prediction/mean': 0.35382357}

# %%
# GET PREDICTIONS
pred_input_func = tf.estimator.inputs.pandas_input_fn(x=X_test, batch_size=10, 
                                                     num_epochs=1,
                                                     shuffle=False)

# %%
predictions = list(model.predict(pred_input_func))
# Out:
# INFO:tensorflow:Restoring parameters from /tmp/tmpe3xlybcj/model.ckpt-1000

# %%
predictions
# Out:
# [{'class_ids': array([1]),
#   'classes': array([b'1'], dtype=object),
#   'logistic': array([0.5180344], dtype=float32),
#   'logits': array([0.07216907], dtype=float32),
#   'probabilities': array([0.48196554, 0.5180344 ], dtype=float32)},
#  {'class_ids': array([1]),
#   'classes': array([b'1'], dtype=object),
#   'logistic': array([0.6300078], dtype=float32),
#   'logits': array([0.53225017], dtype=float32),
#   'probabilities': array([0.36999223, 0.6300078 ], dtype=float32)},
#  {'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.35268882], dtype=float32),
#   'logits': array([-0.60724103], dtype=float32),
#   'probabilities': array([0.6473112 , 0.35268882], dtype=float32)},
#  {'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.32318076], dtype=float32),
#   'logits': array([-0.73919237], dtype=float32),
#   'probabilities': array([0.67681926, 0.32318076], dtype=float32)},
#  {'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.14110452], dtype=float32),
#   'logits': array([-1.8061464], dtype=float32),
#   'probabilities': array([0.8588955 , 0.14110452], dtype=float32)},
#  {'class_ids': array([1]),
#   'classes': array([b'1'], dtype=object),
#   'logistic': array([0.67582256], dtype=float32),
#   'logits': array([0.7346394], dtype=float32),
#   'probabilities': array([0.32417747, 0.67582256], dtype=float32)},
#  {'class_ids': array([1]),
#   'classes': array([b'1'], dtype=object),
#   'logistic': array([0.60190606], dtype=float32),
#   'logits': array([0.41341352], dtype=float32),
#   'probabilities': array([0.3980939 , 0.60190606], dtype=float32)},
#  {'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.29913488], dtype=float32),
#   'logits': array([-0.851421], dtype=float32),
#   'probabilities': array([0.70086515, 0.29913485], dtype=float32)},
#  {'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.20779282], dtype=float32),
#   'logits': array([-1.3382814], dtype=float32),
#   'probabilities': array([0.7922072, 0.2077928], dtype=float32)},
#  {'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.24450581], dtype=float32),
#   'logits': array([-1.128133], dtype=float32),
#   'probabilities': array([0.7554942 , 0.24450582], dtype=float32)},
#  {'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.13576436], dtype=float32),
#   'logits': array([-1.8509247], dtype=float32),
#   'probabilities': array([0.86423564, 0.13576435], dtype=float32)},
#  {'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.1541064], dtype=float32),
#   'logits': array([-1.7027504], dtype=float32),
#   'probabilities': array([0.8458936, 0.1541064], dtype=float32)},
#  {'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.27992037], dtype=float32),
#   'logits': array([-0.9448567], dtype=float32),
#   'probabilities': array([0.72007966, 0.27992037], dtype=float32)},
#  {'class_ids': array([1]),
#   'classes': array([b'1'], dtype=object),
#   'logistic': array([0.5195553], dtype=float32),
#   'logits': array([0.07826102], dtype=float32),
#   'probabilities': array([0.48044473, 0.5195553 ], dtype=float32)},
#  {'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.17908283], dtype=float32),
#   'logits': array([-1.5225737], dtype=float32),
#   'probabilities': array([0.8209172 , 0.17908284], dtype=float32)},
#  {'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.3210907], dtype=float32),
#   'logits': array([-0.7487639], dtype=float32),
#   'probabilities': array([0.67890936, 0.3210907 ], dtype=float32)},
#  {'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.35078317], dtype=float32),
#   'logits': array([-0.6155983], dtype=float32),
#   'probabilities': array([0.6492168 , 0.35078317], dtype=float32)},
#  {'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.13125212], dtype=float32),
#   'logits': array([-1.8899329], dtype=float32),
#   'probabilities': array([0.8687479 , 0.13125212], dtype=float32)},
#  {'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.3487943], dtype=float32),
#   'logits': array([-0.6243432], dtype=float32),
#   'probabilities': array([0.6512057 , 0.34879428], dtype=float32)},
#  {'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.14313933], dtype=float32),
#   'logits': array([-1.7894568], dtype=float32),
#   'probabilities': array([0.8568607 , 0.14313932], dtype=float32)},
#  {'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.19151473], dtype=float32),
#   'logits': array([-1.4401977], dtype=float32),
#   'probabilities': array([0.80848527, 0.19151473], dtype=float32)},
#  {'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.2615803], dtype=float32),
#   'logits': array([-1.0377711], dtype=float32),
#   'probabilities': array([0.7384197, 0.2615803], dtype=float32)},
#  {'class_ids': array([1]),
#   'classes': array([b'1'], dtype=object),
#   'logistic': array([0.6039717], dtype=float32),
#   'logits': array([0.4220419], dtype=float32),
#   'probabilities': array([0.39602825, 0.6039717 ], dtype=float32)},
#  {'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.20872691], dtype=float32),
#   'logits': array([-1.3326163], dtype=float32),
#   'probabilities': array([0.79127306, 0.20872694], dtype=float32)},
#  {'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.17101575], dtype=float32),
#   'logits': array([-1.5784454], dtype=float32),
#   'probabilities': array([0.82898426, 0.17101577], dtype=float32)},
#  {'class_ids': array([1]),
#   'classes': array([b'1'], dtype=object),
#   'logistic': array([0.75694686], dtype=float32),
#   'logits': array([1.1360133], dtype=float32),
#   'probabilities': array([0.24305306, 0.75694686], dtype=float32)},
#  {'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.15754412], dtype=float32),
#   'logits': array([-1.6766157], dtype=float32),
#   'probabilities': array([0.8424559 , 0.15754412], dtype=float32)},
#  {'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.31356165], dtype=float32),
#   'logits': array([-0.7835204], dtype=float32),
#   'probabilities': array([0.6864383 , 0.31356165], dtype=float32)},
#  {'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.10824058], dtype=float32),
#   'logits': array([-2.10884], dtype=float32),
#   'probabilities': array([0.89175946, 0.10824058], dtype=float32)},
#  {'class_ids': array([1]),
#   'classes': array([b'1'], dtype=object),
#   'logistic': array([0.53501576], dtype=float32),
#   'logits': array([0.14029253], dtype=float32),
#   'probabilities': array([0.4649843 , 0.53501576], dtype=float32)},
#  {'class_ids': array([1]),
#   'classes': array([b'1'], dtype=object),
#   'logistic': array([0.9351968], dtype=float32),
#   'logits': array([2.6694021], dtype=float32),
#   'probabilities': array([0.06480319, 0.9351968 ], dtype=float32)},
#  {'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.40560564], dtype=float32),
#   'logits': array([-0.3821615], dtype=float32),
#   'probabilities': array([0.5943944 , 0.40560567], dtype=float32)},
#  {'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.3160609], dtype=float32),
#   'logits': array([-0.7719339], dtype=float32),
#   'probabilities': array([0.6839391, 0.3160609], dtype=float32)},
#  {'class_ids': array([1]),
#   'classes': array([b'1'], dtype=object),
#   'logistic': array([0.51472765], dtype=float32),
#   'logits': array([0.05892766], dtype=float32),
#   'probabilities': array([0.48527232, 0.51472765], dtype=float32)},
#  {'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.23220845], dtype=float32),
#   'logits': array([-1.1958829], dtype=float32),
#   'probabilities': array([0.76779157, 0.23220842], dtype=float32)},
#  {'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.36119667], dtype=float32),
#   'logits': array([-0.570174], dtype=float32),
#   'probabilities': array([0.6388033 , 0.36119664], dtype=float32)},
#  {'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.4585476], dtype=float32),
#   'logits': array([-0.16619122], dtype=float32),
#   'probabilities': array([0.54145247, 0.4585476 ], dtype=float32)},
#  {'class_ids': array([1]),
#   'classes': array([b'1'], dtype=object),
#   'logistic': array([0.5862479], dtype=float32),
#   'logits': array([0.3484758], dtype=float32),
#   'probabilities': array([0.41375208, 0.5862479 ], dtype=float32)},
#  {'class_ids': array([1]),
#   'classes': array([b'1'], dtype=object),
#   'logistic': array([0.745947], dtype=float32),
#   'logits': array([1.0771117], dtype=float32),
#   'probabilities': array([0.25405297, 0.745947  ], dtype=float32)},
#  {'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.33593482], dtype=float32),
#   'logits': array([-0.6814631], dtype=float32),
#   'probabilities': array([0.6640652, 0.3359348], dtype=float32)},
#  {'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.15946983], dtype=float32),
#   'logits': array([-1.662178], dtype=float32),
#   'probabilities': array([0.84053016, 0.15946984], dtype=float32)},
#  {'class_ids': array([1]),
#   'classes': array([b'1'], dtype=object),
#   'logistic': array([0.54367745], dtype=float32),
#   'logits': array([0.17515635], dtype=float32),
#   'probabilities': array([0.45632252, 0.54367745], dtype=float32)},
#  {'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.14778087], dtype=float32),
#   'logits': array([-1.7521131], dtype=float32),
#   'probabilities': array([0.85221916, 0.14778088], dtype=float32)},
#  {'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.49213833], dtype=float32),
#   'logits': array([-0.03144932], dtype=float32),
#   'probabilities': array([0.5078617, 0.4921383], dtype=float32)},
#  {'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.1352594], dtype=float32),
#   'logits': array([-1.8552351], dtype=float32),
#   'probabilities': array([0.8647406, 0.1352594], dtype=float32)},
#  {'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.12276042], dtype=float32),
#   'logits': array([-1.9665455], dtype=float32),
#   'probabilities': array([0.8772396 , 0.12276042], dtype=float32)},
#  {'class_ids': array([1]),
#   'classes': array([b'1'], dtype=object),
#   'logistic': array([0.5895435], dtype=float32),
#   'logits': array([0.36207855], dtype=float32),
#   'probabilities': array([0.41045648, 0.5895435 ], dtype=float32)},
#  {'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.17854173], dtype=float32),
#   'logits': array([-1.5262587], dtype=float32),
#   'probabilities': array([0.8214583 , 0.17854175], dtype=float32)},
#  {'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.18732764], dtype=float32),
#   'logits': array([-1.4674689], dtype=float32),
#   'probabilities': array([0.8126724 , 0.18732762], dtype=float32)},
#  {'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.13729708], dtype=float32),
#   'logits': array([-1.8379233], dtype=float32),
#   'probabilities': array([0.8627029 , 0.13729708], dtype=float32)},
#  {'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.17266892], dtype=float32),
#   'logits': array([-1.5668291], dtype=float32),
#   'probabilities': array([0.8273311, 0.1726689], dtype=float32)},
#  {'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.24428104], dtype=float32),
#   'logits': array([-1.1293502], dtype=float32),
#   'probabilities': array([0.75571895, 0.24428104], dtype=float32)},
#  {'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.25329491], dtype=float32),
#   'logits': array([-1.0811158], dtype=float32),
#   'probabilities': array([0.74670506, 0.25329491], dtype=float32)},
#  {'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.33858672], dtype=float32),
#   'logits': array([-0.6695987], dtype=float32),
#   'probabilities': array([0.66141325, 0.3385867 ], dtype=float32)},
#  {'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.12125225], dtype=float32),
#   'logits': array([-1.9806248], dtype=float32),
#   'probabilities': array([0.87874776, 0.12125225], dtype=float32)},
#  {'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.22154266], dtype=float32),
#   'logits': array([-1.2566991], dtype=float32),
#   'probabilities': array([0.77845734, 0.22154264], dtype=float32)},
#  {'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.20373659], dtype=float32),
#   'logits': array([-1.3631022], dtype=float32),
#   'probabilities': array([0.7962634 , 0.20373659], dtype=float32)},
#  {'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.191996], dtype=float32),
#   'logits': array([-1.4370925], dtype=float32),
#   'probabilities': array([0.808004  , 0.19199598], dtype=float32)},
#  {'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.45680133], dtype=float32),
#   'logits': array([-0.1732266], dtype=float32),
#   'probabilities': array([0.5431987 , 0.45680133], dtype=float32)},
#  {'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.15981378], dtype=float32),
#   'logits': array([-1.6596143], dtype=float32),
#   'probabilities': array([0.8401862 , 0.15981376], dtype=float32)},
#  {'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.20260197], dtype=float32),
#   'logits': array([-1.3701108], dtype=float32),
#   'probabilities': array([0.79739803, 0.20260194], dtype=float32)},
#  {'class_ids': array([1]),
#   'classes': array([b'1'], dtype=object),
#   'logistic': array([0.58735865], dtype=float32),
#   'logits': array([0.35305667], dtype=float32),
#   'probabilities': array([0.41264138, 0.58735865], dtype=float32)},
#  {'class_ids': array([1]),
#   'classes': array([b'1'], dtype=object),
#   'logistic': array([0.6131139], dtype=float32),
#   'logits': array([0.46042025], dtype=float32),
#   'probabilities': array([0.38688612, 0.6131139 ], dtype=float32)},
#  {'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.49621406], dtype=float32),
#   'logits': array([-0.01514411], dtype=float32),
#   'probabilities': array([0.50378597, 0.49621403], dtype=float32)},
#  {'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.35755786], dtype=float32),
#   'logits': array([-0.5859795], dtype=float32),
#   'probabilities': array([0.64244217, 0.35755786], dtype=float32)},
#  {'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.4648466], dtype=float32),
#   'logits': array([-0.14084595], dtype=float32),
#   'probabilities': array([0.53515345, 0.4648466 ], dtype=float32)},
#  {'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.18249221], dtype=float32),
#   'logits': array([-1.499553], dtype=float32),
#   'probabilities': array([0.8175078 , 0.18249221], dtype=float32)},
#  {'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.18453243], dtype=float32),
#   'logits': array([-1.4859364], dtype=float32),
#   'probabilities': array([0.81546754, 0.18453242], dtype=float32)},
#  {'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.13487409], dtype=float32),
#   'logits': array([-1.8585334], dtype=float32),
#   'probabilities': array([0.86512595, 0.13487409], dtype=float32)},
#  {'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.1213077], dtype=float32),
#   'logits': array([-1.9801044], dtype=float32),
#   'probabilities': array([0.87869227, 0.1213077 ], dtype=float32)},
#  {'class_ids': array([1]),
#   'classes': array([b'1'], dtype=object),
#   'logistic': array([0.613126], dtype=float32),
#   'logits': array([0.46047115], dtype=float32),
#   'probabilities': array([0.38687408, 0.613126  ], dtype=float32)},
#  {'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.22248429], dtype=float32),
#   'logits': array([-1.2512474], dtype=float32),
#   'probabilities': array([0.77751577, 0.22248428], dtype=float32)},
#  {'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.433808], dtype=float32),
#   'logits': array([-0.26633108], dtype=float32),
#   'probabilities': array([0.5661919 , 0.43380803], dtype=float32)},
#  {'class_ids': array([1]),
#   'classes': array([b'1'], dtype=object),
#   'logistic': array([0.5669663], dtype=float32),
#   'logits': array([0.26948416], dtype=float32),
#   'probabilities': array([0.4330337, 0.5669663], dtype=float32)},
#  {'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.27927703], dtype=float32),
#   'logits': array([-0.94805056], dtype=float32),
#   'probabilities': array([0.7207229 , 0.27927703], dtype=float32)},
#  {'class_ids': array([1]),
#   'classes': array([b'1'], dtype=object),
#   'logistic': array([0.5957525], dtype=float32),
#   'logits': array([0.38779783], dtype=float32),
#   'probabilities': array([0.40424752, 0.5957525 ], dtype=float32)},
#  {'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.12753658], dtype=float32),
#   'logits': array([-1.9229176], dtype=float32),
#   'probabilities': array([0.87246346, 0.12753657], dtype=float32)},
#  {'class_ids': array([1]),
#   'classes': array([b'1'], dtype=object),
#   'logistic': array([0.59474146], dtype=float32),
#   'logits': array([0.38360167], dtype=float32),
#   'probabilities': array([0.4052585 , 0.59474146], dtype=float32)},
#  {'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.12760273], dtype=float32),
#   'logits': array([-1.9223232], dtype=float32),
#   'probabilities': array([0.8723973 , 0.12760271], dtype=float32)},
#  {'class_ids': array([1]),
#   'classes': array([b'1'], dtype=object),
#   'logistic': array([0.5578537], dtype=float32),
#   'logits': array([0.23245609], dtype=float32),
#   'probabilities': array([0.44214627, 0.5578537 ], dtype=float32)},
#  {'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.3178223], dtype=float32),
#   'logits': array([-0.76379764], dtype=float32),
#   'probabilities': array([0.68217766, 0.3178223 ], dtype=float32)},
#  {'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.15602447], dtype=float32),
#   'logits': array([-1.6881106], dtype=float32),
#   'probabilities': array([0.84397554, 0.15602449], dtype=float32)},
#  {'class_ids': array([1]),
#   'classes': array([b'1'], dtype=object),
#   'logistic': array([0.54113054], dtype=float32),
#   'logits': array([0.16489482], dtype=float32),
#   'probabilities': array([0.45886946, 0.54113054], dtype=float32)},
#  {'class_ids': array([1]),
#   'classes': array([b'1'], dtype=object),
#   'logistic': array([0.5866275], dtype=float32),
#   'logits': array([0.3500409], dtype=float32),
#   'probabilities': array([0.4133725, 0.5866275], dtype=float32)},
#  {'class_ids': array([1]),
#   'classes': array([b'1'], dtype=object),
#   'logistic': array([0.5348474], dtype=float32),
#   'logits': array([0.13961577], dtype=float32),
#   'probabilities': array([0.46515265, 0.5348474 ], dtype=float32)},
#  {'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.1503816], dtype=float32),
#   'logits': array([-1.7316113], dtype=float32),
#   'probabilities': array([0.84961843, 0.15038158], dtype=float32)},
#  {'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.36842382], dtype=float32),
#   'logits': array([-0.5389847], dtype=float32),
#   'probabilities': array([0.63157624, 0.36842382], dtype=float32)},
#  {'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.15011486], dtype=float32),
#   'logits': array([-1.7337005], dtype=float32),
#   'probabilities': array([0.84988517, 0.15011486], dtype=float32)},
#  {'class_ids': array([1]),
#   'classes': array([b'1'], dtype=object),
#   'logistic': array([0.677699], dtype=float32),
#   'logits': array([0.74321747], dtype=float32),
#   'probabilities': array([0.32230097, 0.677699  ], dtype=float32)},
#  {'class_ids': array([1]),
#   'classes': array([b'1'], dtype=object),
#   'logistic': array([0.7915933], dtype=float32),
#   'logits': array([1.3345566], dtype=float32),
#   'probabilities': array([0.20840666, 0.7915933 ], dtype=float32)},
#  {'class_ids': array([1]),
#   'classes': array([b'1'], dtype=object),
#   'logistic': array([0.60427165], dtype=float32),
#   'logits': array([0.42329586], dtype=float32),
#   'probabilities': array([0.39572835, 0.60427165], dtype=float32)},
#  {'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.20950066], dtype=float32),
#   'logits': array([-1.327938], dtype=float32),
#   'probabilities': array([0.7904993 , 0.20950064], dtype=float32)},
#  {'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.4755214], dtype=float32),
#   'logits': array([-0.09799278], dtype=float32),
#   'probabilities': array([0.5244786, 0.4755214], dtype=float32)},
#  {'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.38149187], dtype=float32),
#   'logits': array([-0.48322082], dtype=float32),
#   'probabilities': array([0.6185081 , 0.38149184], dtype=float32)},
#  {'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.42171618], dtype=float32),
#   'logits': array([-0.3157323], dtype=float32),
#   'probabilities': array([0.57828385, 0.42171615], dtype=float32)},
#  {'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.35810575], dtype=float32),
#   'logits': array([-0.58359516], dtype=float32),
#   'probabilities': array([0.6418943 , 0.35810578], dtype=float32)},
#  {'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.39847046], dtype=float32),
#   'logits': array([-0.41184235], dtype=float32),
#   'probabilities': array([0.6015296 , 0.39847046], dtype=float32)},
#  {'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.14829783], dtype=float32),
#   'logits': array([-1.7480142], dtype=float32),
#   'probabilities': array([0.85170215, 0.14829783], dtype=float32)},
#  {'class_ids': array([1]),
#   'classes': array([b'1'], dtype=object),
#   'logistic': array([0.54651666], dtype=float32),
#   'logits': array([0.18660629], dtype=float32),
#   'probabilities': array([0.4534833 , 0.54651666], dtype=float32)},
#  {'class_ids': array([1]),
#   'classes': array([b'1'], dtype=object),
#   'logistic': array([0.5266262], dtype=float32),
#   'logits': array([0.10660565], dtype=float32),
#   'probabilities': array([0.4733738, 0.5266262], dtype=float32)},
#  {'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.23677798], dtype=float32),
#   'logits': array([-1.1704261], dtype=float32),
#   'probabilities': array([0.763222  , 0.23677796], dtype=float32)},
#  {'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.16669047], dtype=float32),
#   'logits': array([-1.6092665], dtype=float32),
#   'probabilities': array([0.83330953, 0.16669047], dtype=float32)},
#  {'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.15221497], dtype=float32),
#   'logits': array([-1.7173333], dtype=float32),
#   'probabilities': array([0.847785  , 0.15221496], dtype=float32)},
#  {'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.2682111], dtype=float32),
#   'logits': array([-1.0037178], dtype=float32),
#   'probabilities': array([0.7317889, 0.2682111], dtype=float32)},
#  {'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.35158437], dtype=float32),
#   'logits': array([-0.61208224], dtype=float32),
#   'probabilities': array([0.6484157 , 0.35158437], dtype=float32)},
#  {'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.13099945], dtype=float32),
#   'logits': array([-1.8921506], dtype=float32),
#   'probabilities': array([0.8690005 , 0.13099945], dtype=float32)},
#  {'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.32813585], dtype=float32),
#   'logits': array([-0.7166285], dtype=float32),
#   'probabilities': array([0.67186415, 0.32813582], dtype=float32)},
#  {'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.2339181], dtype=float32),
#   'logits': array([-1.1863182], dtype=float32),
#   'probabilities': array([0.7660819 , 0.23391809], dtype=float32)},
#  {'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.09726279], dtype=float32),
#   'logits': array([-2.228015], dtype=float32),
#   'probabilities': array([0.9027372, 0.0972628], dtype=float32)},
#  {'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.12969677], dtype=float32),
#   'logits': array([-1.9036424], dtype=float32),
#   'probabilities': array([0.8703032 , 0.12969677], dtype=float32)},
#  {'class_ids': array([1]),
#   'classes': array([b'1'], dtype=object),
#   'logistic': array([0.73323256], dtype=float32),
#   'logits': array([1.0110857], dtype=float32),
#   'probabilities': array([0.2667674 , 0.73323256], dtype=float32)},
#  {'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.15779582], dtype=float32),
#   'logits': array([-1.6747205], dtype=float32),
#   'probabilities': array([0.84220415, 0.15779582], dtype=float32)},
#  {'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.12715068], dtype=float32),
#   'logits': array([-1.92639], dtype=float32),
#   'probabilities': array([0.8728493 , 0.12715068], dtype=float32)},
#  {'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.14919609], dtype=float32),
#   'logits': array([-1.7409202], dtype=float32),
#   'probabilities': array([0.85080385, 0.14919609], dtype=float32)},
#  {'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.47583774], dtype=float32),
#   'logits': array([-0.09672439], dtype=float32),
#   'probabilities': array([0.5241623 , 0.47583774], dtype=float32)},
#  {'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.4181954], dtype=float32),
#   'logits': array([-0.33018607], dtype=float32),
#   'probabilities': array([0.58180463, 0.41819534], dtype=float32)},
#  {'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.21501794], dtype=float32),
#   'logits': array([-1.2949393], dtype=float32),
#   'probabilities': array([0.7849821 , 0.21501796], dtype=float32)},
#  {'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.43840486], dtype=float32),
#   'logits': array([-0.24763834], dtype=float32),
#   'probabilities': array([0.56159514, 0.43840486], dtype=float32)},
#  {'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.17780976], dtype=float32),
#   'logits': array([-1.5312576], dtype=float32),
#   'probabilities': array([0.8221902 , 0.17780975], dtype=float32)},
#  {'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.22735205], dtype=float32),
#   'logits': array([-1.2233237], dtype=float32),
#   'probabilities': array([0.772648  , 0.22735207], dtype=float32)},
#  {'class_ids': array([1]),
#   'classes': array([b'1'], dtype=object),
#   'logistic': array([0.5031026], dtype=float32),
#   'logits': array([0.0124104], dtype=float32),
#   'probabilities': array([0.49689743, 0.5031026 ], dtype=float32)},
#  {'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.47365713], dtype=float32),
#   'logits': array([-0.10546923], dtype=float32),
#   'probabilities': array([0.5263429, 0.4736571], dtype=float32)},
#  {'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.13015074], dtype=float32),
#   'logits': array([-1.8996266], dtype=float32),
#   'probabilities': array([0.86984926, 0.13015074], dtype=float32)},
#  {'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.38511518], dtype=float32),
#   'logits': array([-0.4678924], dtype=float32),
#   'probabilities': array([0.6148848, 0.3851152], dtype=float32)},
#  {'class_ids': array([1]),
#   'classes': array([b'1'], dtype=object),
#   'logistic': array([0.6313073], dtype=float32),
#   'logits': array([0.53782904], dtype=float32),
#   'probabilities': array([0.36869276, 0.6313073 ], dtype=float32)},
#  {'class_ids': array([1]),
#   'classes': array([b'1'], dtype=object),
#   'logistic': array([0.514801], dtype=float32),
#   'logits': array([0.05922151], dtype=float32),
#   'probabilities': array([0.48519897, 0.514801  ], dtype=float32)},
#  {'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.37655705], dtype=float32),
#   'logits': array([-0.5041877], dtype=float32),
#   'probabilities': array([0.62344295, 0.37655702], dtype=float32)},
#  {'class_ids': array([1]),
#   'classes': array([b'1'], dtype=object),
#   'logistic': array([0.54760057], dtype=float32),
#   'logits': array([0.19098055], dtype=float32),
#   'probabilities': array([0.45239943, 0.54760057], dtype=float32)},
#  {'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.22757308], dtype=float32),
#   'logits': array([-1.2220659], dtype=float32),
#   'probabilities': array([0.7724269, 0.2275731], dtype=float32)},
#  {'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.17985122], dtype=float32),
#   'logits': array([-1.5173558], dtype=float32),
#   'probabilities': array([0.82014877, 0.1798512 ], dtype=float32)},
#  {'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.1281735], dtype=float32),
#   'logits': array([-1.9172057], dtype=float32),
#   'probabilities': array([0.87182647, 0.12817349], dtype=float32)},
#  {'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.26534864], dtype=float32),
#   'logits': array([-1.0183514], dtype=float32),
#   'probabilities': array([0.7346514 , 0.26534864], dtype=float32)},
#  {'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.49716988], dtype=float32),
#   'logits': array([-0.01132083], dtype=float32),
#   'probabilities': array([0.50283015, 0.4971698 ], dtype=float32)},
#  {'class_ids': array([1]),
#   'classes': array([b'1'], dtype=object),
#   'logistic': array([0.63929975], dtype=float32),
#   'logits': array([0.57232606], dtype=float32),
#   'probabilities': array([0.36070025, 0.63929975], dtype=float32)},
#  {'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.23006427], dtype=float32),
#   'logits': array([-1.2079483], dtype=float32),
#   'probabilities': array([0.76993567, 0.23006426], dtype=float32)},
#  {'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.16366106], dtype=float32),
#   'logits': array([-1.6312364], dtype=float32),
#   'probabilities': array([0.836339  , 0.16366105], dtype=float32)},
#  {'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.41397685], dtype=float32),
#   'logits': array([-0.3475492], dtype=float32),
#   'probabilities': array([0.58602315, 0.41397685], dtype=float32)},
#  {'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.20520163], dtype=float32),
#   'logits': array([-1.3540955], dtype=float32),
#   'probabilities': array([0.7947984 , 0.20520161], dtype=float32)},
#  {'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.13046844], dtype=float32),
#   'logits': array([-1.8968233], dtype=float32),
#   'probabilities': array([0.8695315 , 0.13046844], dtype=float32)},
#  {'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.18323532], dtype=float32),
#   'logits': array([-1.4945798], dtype=float32),
#   'probabilities': array([0.8167647 , 0.18323532], dtype=float32)},
#  {'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.12988111], dtype=float32),
#   'logits': array([-1.9020103], dtype=float32),
#   'probabilities': array([0.87011886, 0.12988111], dtype=float32)},
#  {'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.4040411], dtype=float32),
#   'logits': array([-0.38865507], dtype=float32),
#   'probabilities': array([0.5959589, 0.4040411], dtype=float32)},
#  {'class_ids': array([1]),
#   'classes': array([b'1'], dtype=object),
#   'logistic': array([0.7564158], dtype=float32),
#   'logits': array([1.1331284], dtype=float32),
#   'probabilities': array([0.24358423, 0.7564158 ], dtype=float32)},
#  {'class_ids': array([1]),
#   'classes': array([b'1'], dtype=object),
#   'logistic': array([0.7516713], dtype=float32),
#   'logits': array([1.1075459], dtype=float32),
#   'probabilities': array([0.24832869, 0.7516713 ], dtype=float32)},
#  {'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.48963374], dtype=float32),
#   'logits': array([-0.041471], dtype=float32),
#   'probabilities': array([0.51036626, 0.48963374], dtype=float32)},
#  {'class_ids': array([1]),
#   'classes': array([b'1'], dtype=object),
#   'logistic': array([0.5028084], dtype=float32),
#   'logits': array([0.01123381], dtype=float32),
#   'probabilities': array([0.49719158, 0.5028084 ], dtype=float32)},
#  {'class_ids': array([1]),
#   'classes': array([b'1'], dtype=object),
#   'logistic': array([0.5684052], dtype=float32),
#   'logits': array([0.27534723], dtype=float32),
#   'probabilities': array([0.43159485, 0.5684052 ], dtype=float32)},
#  {'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.10241063], dtype=float32),
#   'logits': array([-2.1707222], dtype=float32),
#   'probabilities': array([0.8975893 , 0.10241062], dtype=float32)},
#  {'class_ids': array([1]),
#   'classes': array([b'1'], dtype=object),
#   'logistic': array([0.5271148], dtype=float32),
#   'logits': array([0.10856569], dtype=float32),
#   'probabilities': array([0.4728852, 0.5271148], dtype=float32)},
#  {'class_ids': array([1]),
#   'classes': array([b'1'], dtype=object),
#   'logistic': array([0.7522145], dtype=float32),
#   'logits': array([1.1104579], dtype=float32),
#   'probabilities': array([0.24778552, 0.7522145 ], dtype=float32)},
#  {'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.40635216], dtype=float32),
#   'logits': array([-0.3790661], dtype=float32),
#   'probabilities': array([0.59364784, 0.40635216], dtype=float32)},
#  {'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.25127375], dtype=float32),
#   'logits': array([-1.0918304], dtype=float32),
#   'probabilities': array([0.7487262 , 0.25127375], dtype=float32)},
#  {'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.31541002], dtype=float32),
#   'logits': array([-0.7749465], dtype=float32),
#   'probabilities': array([0.68459   , 0.31541005], dtype=float32)},
#  {'class_ids': array([1]),
#   'classes': array([b'1'], dtype=object),
#   'logistic': array([0.56559086], dtype=float32),
#   'logits': array([0.2638842], dtype=float32),
#   'probabilities': array([0.4344091 , 0.56559086], dtype=float32)},
#  {'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.20861602], dtype=float32),
#   'logits': array([-1.333288], dtype=float32),
#   'probabilities': array([0.7913839 , 0.20861602], dtype=float32)},
#  {'class_ids': array([1]),
#   'classes': array([b'1'], dtype=object),
#   'logistic': array([0.6071425], dtype=float32),
#   'logits': array([0.43531656], dtype=float32),
#   'probabilities': array([0.3928575, 0.6071425], dtype=float32)},
#  {'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.4194156], dtype=float32),
#   'logits': array([-0.3251729], dtype=float32),
#   'probabilities': array([0.58058447, 0.4194156 ], dtype=float32)},
#  {'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.4193347], dtype=float32),
#   'logits': array([-0.32550496], dtype=float32),
#   'probabilities': array([0.5806653 , 0.41933474], dtype=float32)},
#  {'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.14004575], dtype=float32),
#   'logits': array([-1.81491], dtype=float32),
#   'probabilities': array([0.8599543 , 0.14004575], dtype=float32)},
#  {'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.1820348], dtype=float32),
#   'logits': array([-1.5026219], dtype=float32),
#   'probabilities': array([0.8179652, 0.1820348], dtype=float32)},
#  {'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.18461353], dtype=float32),
#   'logits': array([-1.4853977], dtype=float32),
#   'probabilities': array([0.8153865 , 0.18461351], dtype=float32)},
#  {'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.4041035], dtype=float32),
#   'logits': array([-0.38839597], dtype=float32),
#   'probabilities': array([0.5958965, 0.4041035], dtype=float32)},
#  {'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.13440381], dtype=float32),
#   'logits': array([-1.8625698], dtype=float32),
#   'probabilities': array([0.86559623, 0.1344038 ], dtype=float32)},
#  {'class_ids': array([1]),
#   'classes': array([b'1'], dtype=object),
#   'logistic': array([0.7203704], dtype=float32),
#   'logits': array([0.94629955], dtype=float32),
#   'probabilities': array([0.27962965, 0.7203704 ], dtype=float32)},
#  {'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.17341968], dtype=float32),
#   'logits': array([-1.5615824], dtype=float32),
#   'probabilities': array([0.8265803 , 0.17341968], dtype=float32)},
#  {'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.49044406], dtype=float32),
#   'logits': array([-0.03822863], dtype=float32),
#   'probabilities': array([0.509556, 0.490444], dtype=float32)},
#  {'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.13943252], dtype=float32),
#   'logits': array([-1.8200113], dtype=float32),
#   'probabilities': array([0.8605675 , 0.13943252], dtype=float32)},
#  {'class_ids': array([1]),
#   'classes': array([b'1'], dtype=object),
#   'logistic': array([0.66044635], dtype=float32),
#   'logits': array([0.6652839], dtype=float32),
#   'probabilities': array([0.33955362, 0.66044635], dtype=float32)},
#  {'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.2997163], dtype=float32),
#   'logits': array([-0.8486493], dtype=float32),
#   'probabilities': array([0.70028377, 0.29971626], dtype=float32)},
#  {'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.19012383], dtype=float32),
#   'logits': array([-1.4492058], dtype=float32),
#   'probabilities': array([0.80987614, 0.19012383], dtype=float32)},
#  {'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.3209868], dtype=float32),
#   'logits': array([-0.7492405], dtype=float32),
#   'probabilities': array([0.6790132, 0.3209868], dtype=float32)},
#  {'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.32410097], dtype=float32),
#   'logits': array([-0.7349886], dtype=float32),
#   'probabilities': array([0.675899  , 0.32410097], dtype=float32)},
#  {'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.17065309], dtype=float32),
#   'logits': array([-1.5810058], dtype=float32),
#   'probabilities': array([0.82934695, 0.17065309], dtype=float32)},
#  {'class_ids': array([1]),
#   'classes': array([b'1'], dtype=object),
#   'logistic': array([0.6964528], dtype=float32),
#   'logits': array([0.83046293], dtype=float32),
#   'probabilities': array([0.30354717, 0.6964528 ], dtype=float32)},
#  {'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.19201057], dtype=float32),
#   'logits': array([-1.4369986], dtype=float32),
#   'probabilities': array([0.8079895 , 0.19201055], dtype=float32)},
#  {'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.17628966], dtype=float32),
#   'logits': array([-1.5416906], dtype=float32),
#   'probabilities': array([0.8237104 , 0.17628965], dtype=float32)},
#  {'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.270163], dtype=float32),
#   'logits': array([-0.9937957], dtype=float32),
#   'probabilities': array([0.729837, 0.270163], dtype=float32)},
#  {'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.43732777], dtype=float32),
#   'logits': array([-0.25201428], dtype=float32),
#   'probabilities': array([0.56267226, 0.43732777], dtype=float32)},
#  {'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.25497472], dtype=float32),
#   'logits': array([-1.0722537], dtype=float32),
#   'probabilities': array([0.74502534, 0.25497472], dtype=float32)},
#  {'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.12128427], dtype=float32),
#   'logits': array([-1.9803243], dtype=float32),
#   'probabilities': array([0.87871575, 0.12128428], dtype=float32)},
#  {'class_ids': array([1]),
#   'classes': array([b'1'], dtype=object),
#   'logistic': array([0.829842], dtype=float32),
#   'logits': array([1.584508], dtype=float32),
#   'probabilities': array([0.17015798, 0.829842  ], dtype=float32)},
#  {'class_ids': array([1]),
#   'classes': array([b'1'], dtype=object),
#   'logistic': array([0.61957026], dtype=float32),
#   'logits': array([0.48772454], dtype=float32),
#   'probabilities': array([0.38042971, 0.61957026], dtype=float32)},
#  {'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.48882326], dtype=float32),
#   'logits': array([-0.04471433], dtype=float32),
#   'probabilities': array([0.5111767 , 0.48882326], dtype=float32)},
#  {'class_ids': array([1]),
#   'classes': array([b'1'], dtype=object),
#   'logistic': array([0.715708], dtype=float32),
#   'logits': array([0.92327034], dtype=float32),
#   'probabilities': array([0.284292, 0.715708], dtype=float32)},
#  {'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.1319917], dtype=float32),
#   'logits': array([-1.8834622], dtype=float32),
#   'probabilities': array([0.8680084, 0.1319917], dtype=float32)},
#  {'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.12774503], dtype=float32),
#   'logits': array([-1.9210454], dtype=float32),
#   'probabilities': array([0.87225497, 0.12774503], dtype=float32)},
#  {'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.21508755], dtype=float32),
#   'logits': array([-1.294527], dtype=float32),
#   'probabilities': array([0.7849124 , 0.21508755], dtype=float32)},
#  {'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.32842433], dtype=float32),
#   'logits': array([-0.7153202], dtype=float32),
#   'probabilities': array([0.67157567, 0.32842433], dtype=float32)},
#  {'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.32963288], dtype=float32),
#   'logits': array([-0.709846], dtype=float32),
#   'probabilities': array([0.6703671 , 0.32963285], dtype=float32)},
#  {'class_ids': array([1]),
#   'classes': array([b'1'], dtype=object),
#   'logistic': array([0.5149951], dtype=float32),
#   'logits': array([0.05999827], dtype=float32),
#   'probabilities': array([0.48500493, 0.5149951 ], dtype=float32)},
#  {'class_ids': array([1]),
#   'classes': array([b'1'], dtype=object),
#   'logistic': array([0.5568812], dtype=float32),
#   'logits': array([0.22851396], dtype=float32),
#   'probabilities': array([0.4431188, 0.5568812], dtype=float32)},
#  {'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.39225945], dtype=float32),
#   'logits': array([-0.43782473], dtype=float32),
#   'probabilities': array([0.6077406 , 0.39225942], dtype=float32)},
#  {'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.34661818], dtype=float32),
#   'logits': array([-0.6339377], dtype=float32),
#   'probabilities': array([0.65338176, 0.3466182 ], dtype=float32)},
#  {'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.33997256], dtype=float32),
#   'logits': array([-0.6634166], dtype=float32),
#   'probabilities': array([0.66002744, 0.33997253], dtype=float32)},
#  {'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.18666519], dtype=float32),
#   'logits': array([-1.4718263], dtype=float32),
#   'probabilities': array([0.8133349 , 0.18666518], dtype=float32)},
#  {'class_ids': array([1]),
#   'classes': array([b'1'], dtype=object),
#   'logistic': array([0.58668834], dtype=float32),
#   'logits': array([0.35029185], dtype=float32),
#   'probabilities': array([0.41331163, 0.58668834], dtype=float32)},
#  {'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.1328819], dtype=float32),
#   'logits': array([-1.8757145], dtype=float32),
#   'probabilities': array([0.8671181, 0.1328819], dtype=float32)},
#  {'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.22235169], dtype=float32),
#   'logits': array([-1.252014], dtype=float32),
#   'probabilities': array([0.77764827, 0.22235169], dtype=float32)},
#  {'class_ids': array([1]),
#   'classes': array([b'1'], dtype=object),
#   'logistic': array([0.54409647], dtype=float32),
#   'logits': array([0.17684531], dtype=float32),
#   'probabilities': array([0.45590353, 0.54409647], dtype=float32)},
#  {'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.33061612], dtype=float32),
#   'logits': array([-0.70539975], dtype=float32),
#   'probabilities': array([0.6693839 , 0.33061612], dtype=float32)},
#  {'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.19305441], dtype=float32),
#   'logits': array([-1.4302841], dtype=float32),
#   'probabilities': array([0.8069456 , 0.19305442], dtype=float32)},
#  {'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.26533833], dtype=float32),
#   'logits': array([-1.0184042], dtype=float32),
#   'probabilities': array([0.7346617 , 0.26533833], dtype=float32)},
#  {'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.22366597], dtype=float32),
#   'logits': array([-1.2444292], dtype=float32),
#   'probabilities': array([0.77633405, 0.22366597], dtype=float32)},
#  {'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.13708517], dtype=float32),
#   'logits': array([-1.8397136], dtype=float32),
#   'probabilities': array([0.8629148 , 0.13708517], dtype=float32)},
#  {'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.20993055], dtype=float32),
#   'logits': array([-1.3253441], dtype=float32),
#   'probabilities': array([0.7900694 , 0.20993054], dtype=float32)},
#  {'class_ids': array([1]),
#   'classes': array([b'1'], dtype=object),
#   'logistic': array([0.5437393], dtype=float32),
#   'logits': array([0.17540562], dtype=float32),
#   'probabilities': array([0.45626068, 0.5437393 ], dtype=float32)},
#  {'class_ids': array([1]),
#   'classes': array([b'1'], dtype=object),
#   'logistic': array([0.69033366], dtype=float32),
#   'logits': array([0.8016796], dtype=float32),
#   'probabilities': array([0.30966634, 0.69033366], dtype=float32)},
#  {'class_ids': array([1]),
#   'classes': array([b'1'], dtype=object),
#   'logistic': array([0.620739], dtype=float32),
#   'logits': array([0.49268603], dtype=float32),
#   'probabilities': array([0.379261, 0.620739], dtype=float32)},
#  {'class_ids': array([1]),
#   'classes': array([b'1'], dtype=object),
#   'logistic': array([0.65662843], dtype=float32),
#   'logits': array([0.64830494], dtype=float32),
#   'probabilities': array([0.34337163, 0.65662843], dtype=float32)},
#  {'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.43717608], dtype=float32),
#   'logits': array([-0.2526307], dtype=float32),
#   'probabilities': array([0.5628239, 0.4371761], dtype=float32)},
#  {'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.3025471], dtype=float32),
#   'logits': array([-0.83519804], dtype=float32),
#   'probabilities': array([0.6974529, 0.3025471], dtype=float32)},
#  {'class_ids': array([1]),
#   'classes': array([b'1'], dtype=object),
#   'logistic': array([0.5094059], dtype=float32),
#   'logits': array([0.03762817], dtype=float32),
#   'probabilities': array([0.49059406, 0.5094059 ], dtype=float32)},
#  {'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.17227037], dtype=float32),
#   'logits': array([-1.5696214], dtype=float32),
#   'probabilities': array([0.82772964, 0.17227037], dtype=float32)},
#  {'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.15803838], dtype=float32),
#   'logits': array([-1.6728966], dtype=float32),
#   'probabilities': array([0.8419617 , 0.15803838], dtype=float32)},
#  {'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.16479564], dtype=float32),
#   'logits': array([-1.6229703], dtype=float32),
#   'probabilities': array([0.83520436, 0.16479562], dtype=float32)},
#  {'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.46020362], dtype=float32),
#   'logits': array([-0.15952313], dtype=float32),
#   'probabilities': array([0.5397964 , 0.46020356], dtype=float32)},
#  {'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.05240016], dtype=float32),
#   'logits': array([-2.8950226], dtype=float32),
#   'probabilities': array([0.9475999 , 0.05240016], dtype=float32)},
#  {'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.24419415], dtype=float32),
#   'logits': array([-1.129821], dtype=float32),
#   'probabilities': array([0.75580585, 0.24419415], dtype=float32)},
#  {'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.17034994], dtype=float32),
#   'logits': array([-1.5831492], dtype=float32),
#   'probabilities': array([0.82965004, 0.17034993], dtype=float32)},
#  {'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.26814088], dtype=float32),
#   'logits': array([-1.0040755], dtype=float32),
#   'probabilities': array([0.73185915, 0.26814085], dtype=float32)},
#  {'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.2286351], dtype=float32),
#   'logits': array([-1.2160343], dtype=float32),
#   'probabilities': array([0.7713649 , 0.22863509], dtype=float32)},
#  {'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.27738482], dtype=float32),
#   'logits': array([-0.9574712], dtype=float32),
#   'probabilities': array([0.7226152, 0.2773848], dtype=float32)},
#  {'class_ids': array([1]),
#   'classes': array([b'1'], dtype=object),
#   'logistic': array([0.75786847], dtype=float32),
#   'logits': array([1.1410286], dtype=float32),
#   'probabilities': array([0.24213156, 0.75786847], dtype=float32)},
#  {'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.16813521], dtype=float32),
#   'logits': array([-1.5989015], dtype=float32),
#   'probabilities': array([0.83186483, 0.16813521], dtype=float32)},
#  {'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.12012286], dtype=float32),
#   'logits': array([-1.9912673], dtype=float32),
#   'probabilities': array([0.87987715, 0.12012286], dtype=float32)},
#  {'class_ids': array([1]),
#   'classes': array([b'1'], dtype=object),
#   'logistic': array([0.5691422], dtype=float32),
#   'logits': array([0.27835226], dtype=float32),
#   'probabilities': array([0.43085778, 0.5691422 ], dtype=float32)},
#  {'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.4739666], dtype=float32),
#   'logits': array([-0.10422796], dtype=float32),
#   'probabilities': array([0.52603346, 0.4739666 ], dtype=float32)},
#  {'class_ids': array([1]),
#   'classes': array([b'1'], dtype=object),
#   'logistic': array([0.8205422], dtype=float32),
#   'logits': array([1.520025], dtype=float32),
#   'probabilities': array([0.17945784, 0.8205422 ], dtype=float32)},
#  {'class_ids': array([1]),
#   'classes': array([b'1'], dtype=object),
#   'logistic': array([0.6319364], dtype=float32),
#   'logits': array([0.5405328], dtype=float32),
#   'probabilities': array([0.36806366, 0.6319364 ], dtype=float32)},
#  {'class_ids': array([0]),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.12127572], dtype=float32),
#   'logits': array([-1.9804046], dtype=float32),
#   'probabilities': array([0.8787243 , 0.12127571], dtype=float32)},
#  {'class_ids': array([1]),
#   'classes': array([b'1'], dtype=object),
#   'logistic': array([0.61595035], dtype=float32),
#   'logits': array([0.47239435], dtype=float32),
#   'probabilities': array([0.38404968, 0.61595035], dtype=float32)}]

# %%
##############################
# DENSE NEURAL NETWORK CLASSIFIER
##############################

# %%
# we need to embed categorical feature columns
embedded_assigned_group = tf.feature_column.embedding_column(assigned_group, dimension=4)

# %%
# replace the assigned group with our new embeddings assigned group
feat_cols = [num_preg, plasma_gluc, dias_press, tricep, insulin, bmi, diabetes_predigree, 
            embedded_assigned_group,age_bucket]

# %%
input_func = tf.estimator.inputs.pandas_input_fn(X_train, y_train, 
                                                 batch_size =10, 
                                                 num_epochs=1000, 
                                                 shuffle=True)

# %%
# 3 layers and each of the layers has 10 neurons densely connected in the next layer
dnn_model = tf.estimator.DNNClassifier(hidden_units=[10,20,20,20,10], feature_columns=feat_cols, n_classes=2)
# Out:
# INFO:tensorflow:Using default config.
# WARNING:tensorflow:Using temporary folder as model directory: /tmp/tmpqdckuw42
# INFO:tensorflow:Using config: {'_keep_checkpoint_every_n_hours': 10000, '_save_summary_steps': 100, '_keep_checkpoint_max': 5, '_task_id': 0, '_num_ps_replicas': 0, '_is_chief': True, '_tf_random_seed': None, '_num_worker_replicas': 1, '_service': None, '_master': '', '_log_step_count_steps': 100, '_save_checkpoints_secs': 600, '_session_config': None, '_cluster_spec': <tensorflow.python.training.server_lib.ClusterSpec object at 0x7fb92f53a860>, '_save_checkpoints_steps': None, '_model_dir': '/tmp/tmpqdckuw42', '_task_type': 'worker'}

# %%
dnn_model.train(input_fn=input_func, steps=1000)
# Out:
# INFO:tensorflow:Create CheckpointSaverHook.
# INFO:tensorflow:Saving checkpoints for 1 into /tmp/tmpqdckuw42/model.ckpt.
# INFO:tensorflow:loss = 7.1604066, step = 1
# INFO:tensorflow:global_step/sec: 40.012
# INFO:tensorflow:loss = 5.166228, step = 101 (2.501 sec)
# INFO:tensorflow:global_step/sec: 41.0417
# INFO:tensorflow:loss = 5.325469, step = 201 (2.436 sec)
# INFO:tensorflow:global_step/sec: 40.1392
# INFO:tensorflow:loss = 3.4941585, step = 301 (2.491 sec)
# INFO:tensorflow:global_step/sec: 37.18
# INFO:tensorflow:loss = 5.6158056, step = 401 (2.691 sec)
# INFO:tensorflow:global_step/sec: 38.957
# INFO:tensorflow:loss = 4.5501266, step = 501 (2.564 sec)
# INFO:tensorflow:global_step/sec: 37.3216
# INFO:tensorflow:loss = 6.527951, step = 601 (2.680 sec)
# INFO:tensorflow:global_step/sec: 40.276
# INFO:tensorflow:loss = 4.692581, step = 701 (2.481 sec)
# INFO:tensorflow:global_step/sec: 68.0565
# INFO:tensorflow:loss = 3.0658052, step = 801 (1.471 sec)
# INFO:tensorflow:global_step/sec: 36.435
# INFO:tensorflow:loss = 3.3471985, step = 901 (2.744 sec)
# INFO:tensorflow:Saving checkpoints for 1000 into /tmp/tmpqdckuw42/model.ckpt.
# INFO:tensorflow:Loss for final step: 5.4616356.

# %%
eval_input_func = tf.estimator.inputs.pandas_input_fn(x= X_test, y=y_test, 
                                                      batch_size=10, num_epochs=1, shuffle=False)

# %%
dnn_model.evaluate(eval_input_func)
# Out:
# WARNING:tensorflow:Casting <dtype: 'float32'> labels to bool.
# WARNING:tensorflow:Casting <dtype: 'float32'> labels to bool.
# INFO:tensorflow:Starting evaluation at 2018-03-28-00:59:18
# INFO:tensorflow:Restoring parameters from /tmp/tmpqdckuw42/model.ckpt-1000
# INFO:tensorflow:Finished evaluation at 2018-03-28-00:59:19
# INFO:tensorflow:Saving dict for global step 1000: accuracy = 0.7532467, accuracy_baseline = 0.64935064, auc = 0.8332921, auc_precision_recall = 0.707161, average_loss = 0.47855672, global_step = 1000, label/mean = 0.35064936, loss = 4.606108, prediction/mean = 0.34996653
# {'accuracy': 0.7532467,
#  'accuracy_baseline': 0.64935064,
#  'auc': 0.8332921,
#  'auc_precision_recall': 0.707161,
#  'average_loss': 0.47855672,
#  'global_step': 1000,
#  'label/mean': 0.35064936,
#  'loss': 4.606108,
#  'prediction/mean': 0.34996653}
