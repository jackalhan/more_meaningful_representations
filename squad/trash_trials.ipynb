# %%
import os
import h5py
import json
import pandas as pd
# Out:
# /home/jackalhan/Development/github/bilm-tf/venv/lib/python3.5/site-packages/h5py/__init__.py:36: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   from ._conv import register_converters as _register_converters

# %%
import tensorflow as tf

# %%
#a = tf.constant([[100, 110], [10, 20], [1000, 1100]])
a = tf.random_uniform(shape=[3, 150,1024])

# %%
b = tf.reduce_mean(a)
c = tf.reduce_mean(a, axis=0)
d = tf.reduce_mean(a, axis=1)
e = tf.reduce_mean(a, axis=2)
f = tf.reduce_mean(a, axis=[0,1])

# %%
session = tf.Session()

# %%
print("INPUT")
print(session.run(a))
print("REDUCE MEAN")
print(session.run(b))
print("REDUCE MEAN (shape)")
print(b.shape)
print("REDUCE MEAN AXIS 0")
print(session.run(c))
print("REDUCE MEAN AXIS 0 (shape)")
print(c.shape)
print("REDUCE MEAN AXIS 1")
print(session.run(d))
print("REDUCE MEAN AXIS 1 (shape)")
print(d.shape)
print("REDUCE MEAN AXIS 2")
print(session.run(e))
print("REDUCE MEAN AXIS 2 (shape)")
print(e.shape)
print("REDUCE MEAN AXIS 0,1")
print(session.run(f))
print("REDUCE MEAN AXIS 0,1 (shape)")
print(f.shape)
# Out:
# INPUT
# [[[0.14361286 0.74463546 0.05528474 ... 0.42196012 0.83750486 0.32525635]
#   [0.8512775  0.40255404 0.6226797  ... 0.9696106  0.5934336  0.24274111]
#   [0.29692662 0.8753855  0.28486526 ... 0.33133066 0.5703893  0.58597136]
#   ...
#   [0.29707527 0.51404476 0.9240384  ... 0.34801102 0.2070018  0.25367928]
#   [0.78632    0.36166894 0.41988075 ... 0.8387991  0.7794237  0.6020839 ]
#   [0.13407731 0.9202765  0.29769742 ... 0.3187636  0.06853759 0.86523616]]
#
#  [[0.7800853  0.72759056 0.7789978  ... 0.67362404 0.9373268  0.42324948]
#   [0.37501156 0.8671254  0.78329694 ... 0.5555297  0.54702055 0.6134634 ]
#   [0.96783996 0.40766132 0.52161574 ... 0.35092616 0.90680766 0.9696127 ]
#   ...
#   [0.41031122 0.18462563 0.9901916  ... 0.69740224 0.1939987  0.6404489 ]
#   [0.8943119  0.26174676 0.8990778  ... 0.17971289 0.2937343  0.3150028 ]
#   [0.16068578 0.6621947  0.736832   ... 0.26410758 0.33290815 0.64911294]]
#
#  [[0.02733278 0.7306404  0.77339077 ... 0.8486546  0.28127265 0.78303254]
#   [0.50643885 0.48914862 0.3480724  ... 0.05071056 0.12581313 0.29332268]
#   [0.25850832 0.63159037 0.09011614 ... 0.72232604 0.53313196 0.20330274]
#   ...
#   [0.58070576 0.07382929 0.33641398 ... 0.60337627 0.9115578  0.20375633]
#   [0.38657224 0.679922   0.10161757 ... 0.36153734 0.42531157 0.79473567]
#   [0.7353766  0.60335934 0.01275849 ... 0.45492113 0.08748543 0.6904868 ]]]
# REDUCE MEAN
# 0.49971172
# REDUCE MEAN (shape)
# ()
# REDUCE MEAN AXIS 0
#   0.5016013  0.5127604  0.5004666  0.5071571  0.50709826 0.49875098
#   0.5044946  0.49990067 0.50560117 0.51979804 0.50786597 0.49512005
#   0.47231016 0.50364107 0.49779835 0.49497375 0.5036749  0.5029915
#   0.5037104  0.4955099  0.50554514 0.49919766 0.49304134 0.50171185
#   0.49805686 0.5105939  0.49230212 0.5003674  0.49887246 0.5073447
#   0.5117313  0.5029121  0.49053848 0.50216043 0.5120993  0.49420065
#   0.5199971  0.50530076 0.5103589  0.49742645 0.53223246 0.4870426
#   0.51106185 0.4848     0.50040394 0.49363    0.50094604 0.49609667
#   0.50109977 0.49263608 0.5173416  0.49549434 0.50794363 0.5039189
#   0.50891066 0.49523237 0.5100342  0.49108428 0.49834245 0.4979328
#   0.5087775  0.49465856 0.5096775  0.51222503 0.49221557 0.5138406
#   0.5137484  0.50964165 0.48674798 0.49510348 0.52039194 0.5115186
#   0.4881859  0.49377853 0.5072457  0.5061797  0.49955016 0.49610287]]
# REDUCE MEAN AXIS 2 (shape)
# (3, 150)
# REDUCE MEAN AXIS 0,1
# [0.50913197 0.48908952 0.50308615 ... 0.5092334  0.5095763  0.48045328]
# REDUCE MEAN AXIS 0,1 (shape)
# (1024,)

# %%
#dataset_type = 'train'
dataset_type = 'dev'
dataset_version = 'v1.1'

index_field = ['Unnamed: 0']

# required files
_basepath = '/home/jackalhan/Development/github/bilm-tf/squad'
datadir = os.path.join(_basepath, dataset_type)
modeldir = os.path.join(_basepath, 'model')

# %%
filename = 'file.hdf5'
f = h5py.File(filename, 'r')

# List all groups
print("Keys: %s" % f.keys())
a_group_key = list(f.keys())[0]

# Get the data
data = list(f[a_group_key])

# %%
paragraphs_with_mean = []
questions_with_mean = []
items = [dict({'type':'question', 
                     'list':questions_with_mean, 
                     'source_file':embedding_question_file_as_h5py,
                     'destination_file': embedding_mean_question_file_as_h5py}), 
              dict({'type':'paragraph', 
                     'list':paragraphs_with_mean, 
                     'source_file':embedding_paragraph_file_as_h5py,
                     'destination_file': embedding_mean_paragraph_file_as_h5py})
              ]
for vals in items:
    print(vals['type'], 'is getting processed!!!')
    config = tf.ConfigProto(allow_soft_placement=True)
    
    with h5py.File(vals['source_file'], 'r') as fin:
        data_as_array = np.array(fin)
    
    print(data_as_array.shape)
    with tf.Session(config=config) as sess:
        sess.run(tf.global_variables_initializer())
         h5py.File(vals['destination_file'], 'w') as fout:
            #for _ in tqdm_notebook(fin, total=len(fin)):
                mean_vectors = sess.run(tf.reduce_mean(fin[str(_)][...], axis=[0,1]))
                
                data_as_array
                x = tf.placeholder(tf.float32, [100, 250])
                norm = tf.sqrt(tf.reduce_sum(tf.square(x), 1, keep_dims=True))
                res = x / norm
                vals['list'].append(mean_vector)
                ds = fout.create_dataset(
                        '{}'.format(_),
                        mean_vector.shape, dtype='float32',
                        data=mean_vector)
